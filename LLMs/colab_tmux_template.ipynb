# %% [markdown]
# # Running {name} in Google Colab

# %% [markdown]
# ### Introduction:

# %% [markdown]
# ### References
#
# - [name] ( link )

# %% [markdown]
# ## Environment Setup

# %%
# pip installs
# %%capture
# %%bash
pip install ollama

# %%
# authentication tokens

# %%
# Python package imports
import requests
from time import sleep
from datetime import datetime, timezone
from google.colab import output

# %% [markdown]
# ## Setup {name}

# %% [markdown]
# ### Install {name}

# %%
# %%writefile /tmp/tmux.{name}.setup.sh
# #!/bin/bash
#
# # ollama service install and launch
# # - remove semaphore file
# # - a log folder
# # - a log file
# rm -f /tmp/.done.{name}
# mkdir -p /tmp/{name}-logs/
# exec > >(tee /tmp/{name}-logs/{name}.setup.log) 2>&1
#
#
#
# # - create semaphore file
# touch /tmp/.done.{name}

# %%
# run a tmux session for installation
# %%bash

# Start and run the setup script
tmux new -s {name}-setup -d 'bash /tmp/tmux.{name}.setup.sh'

# %% [markdown]
# ## Wait for service to start and display IP

# %%
url = "http://localhost:port/path"

print("Waiting for {name} to start")
for i in range(1,301):
  try:
    requests.head( url )
    print()
    break
  except:
    print("=", end="")
    if i % 30 == 0 :
      print(f" -- {i:3}s")
    sleep(1)
print(f"{i} seconds")

print("{name} has started")
output.serve_kernel_port_as_window(port)
